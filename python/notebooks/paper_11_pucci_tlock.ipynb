# %% [markdown]
# # Paper 11: Pucci (2019) — Treasury Lock
#
# See `test_paper_11_pucci_tlock.py` for validation assertions.

# %%
import sys; sys.path.insert(0, '..')
import math, numpy as np, matplotlib.pyplot as plt
from pricebook.viz import configure_theme, apply_theme
configure_theme(dark=False)
print('Paper 11 notebook ready')

# %% [markdown]
# ## Summary
# | Validation | Result |
# |---|---|
# | Forward dirty ≈ 104.74 | ✓ |
# | Positive carry (yield > repo) | ✓ |
# | Overhedge error < 0.1 | ✓ |
# | Delta positive long | ✓ |
