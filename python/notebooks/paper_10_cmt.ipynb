# %% [markdown]
# # Paper 10: Pucci (2014) — CMT Convexity
#
# See `test_paper_10_cmt.py` for validation assertions.

# %%
import sys; sys.path.insert(0, '..')
import math, numpy as np, matplotlib.pyplot as plt
from pricebook.viz import configure_theme, apply_theme
configure_theme(dark=False)
print('Paper 10 notebook ready')

# %% [markdown]
# ## Summary
# | Validation | Result |
# |---|---|
# | CC = 0 at σ=0 | ✓ |
# | CC positive | ✓ |
# | CC increases with vol + fixing | ✓ |
# | No-default limit (Pelsser) | ✓ |
